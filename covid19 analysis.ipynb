# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel(r"C:\Users\user\Desktop\covid19.xlsx")
print(data.head())
# Out:
#       country  deceased   infected  recovered       tested
# 0     Algeria    6875.0   265818.0     178374          NaN
# 1     Austria   19827.0  4253741.0    4186945  184874698.0
# 2  Azerbaijan    9709.0   792638.0     782869    6838458.0
# 3     Bahrain    1479.0   577652.0     570461    9784846.0
# 4     Belgium   31165.0  3972963.0          0   33313880.0

# %%
print(data.tail())
# Out:
#            country  deceased    infected  recovered  tested
# 40     Switzerland   12460.0   2433265.0          0     0.0
# 41          Turkey       0.0         0.0          0     0.0
# 42  United Kingdom  181424.0  18393951.0          0     0.0
# 43   United States  997083.0  82301126.0          0     0.0
# 44         Vietnam       NaN  10696630.0    9355040     0.0

# %%
print(data.columns)
# Out:
# Index(['country', 'deceased', 'infected', 'recovered', 'tested'], dtype='object')

# %%
print(data.describe())
# Out:
#             deceased      infected     recovered        tested
# count      44.000000  4.400000e+01  4.500000e+01  4.400000e+01
# mean    89829.931818  6.727885e+06  2.249424e+06  1.377525e+07
# std    191948.832022  1.468218e+07  6.849647e+06  3.725582e+07
# min         0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 25%      5095.250000  3.555180e+05  0.000000e+00  0.000000e+00
# 50%     19362.000000  1.847886e+06  0.000000e+00  0.000000e+00
# 75%     66989.250000  4.309834e+06  7.828690e+05  9.643823e+06
# max    997083.000000  8.230113e+07  4.258224e+07  1.848747e+08

# %%
#print(data.isnull()) to display void values

# %%
print(sns.relplot(x="infected",y="recovered", data=data))

# %%
print(sns.pairplot(data))

# %%
print(sns.relplot(x="infected",y="deceased",kind='line',data=data))

# %%
print(sns.catplot(x="country",y="deceased",data=data))
