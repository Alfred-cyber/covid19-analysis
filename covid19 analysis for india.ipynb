# %%
#first we import the libraries we need
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#secondly we read the workbook we want to work with
df = pd.read_csv(r"C:\Users\user\AppData\Local\Temp\Rar$DIa0.203\covid_india_states.csv")
#let me display the first five rows of the workbook
print(df.head(5))
# Out:
#    Unnamed: 0                        State  Total Confirmed cases  Cured  \
# 0           0  Andaman and Nicobar Islands                     33     16
# 1           1               Andhra Pradesh                   1463    403
# 2           2            Arunachal Pradesh                      1      1
# 3           3                        Assam                     42     29
# 4           4                        Bihar                    426     82
#
#    Death
# 0      0
# 1     33
# 2      0
# 3      1
# 4      2

# %%
#let me also display the last five rows of the workbook
print(df.tail(5))
# Out:
#     Unnamed: 0          State  Total Confirmed cases  Cured  Death
# 27          27      Telengana                   1039    441     26
# 28          28        Tripura                      2      2      0
# 29          29    Uttarakhand                     57     36      0
# 30          30  Uttar Pradesh                   2281    555     41
# 31          31    West Bengal                    795    139     33

# %%
#let's see the column names for the purpose of indexing
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'State', 'Total Confirmed cases', 'Cured', 'Death'], dtype='object')

# %%
#lets see a summary of the dataset
print(df.describe())
# Out:
#        Unnamed: 0  Total Confirmed cases        Cured       Death
# count   32.000000              32.000000    32.000000   32.000000
# mean    15.500000            1092.875000   283.281250   36.000000
# std      9.380832            2075.891456   427.312172   89.232209
# min      0.000000               1.000000     0.000000    0.000000
# 25%      7.750000              30.250000    16.000000    0.000000
# 50%     15.500000             228.000000    61.500000    2.500000
# 75%     23.250000            1145.000000   412.500000   28.500000
# max     31.000000           10498.000000  1773.000000  459.000000

# %%
#let me plot the graph of the total confirmed cases against the cured
print(sns.relplot(x="Total Confirmed cases", y="Cured", data=df))

# %%
print(sns.pairplot(df))

# %%
#let me also observe the line curve of death against the cured people to find a relationship
print(sns.relplot(x="Death", y="Cured",kind="line",data=df))

# %%
print(sns.catplot(x="Total Confirmed cases", y="Cured",data=df))
